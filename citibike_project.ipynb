# %%
#Dependencies
import os
import pandas as pd

# %%
#path
# file_1 = os.path.join('Data','2013-06-citibike-tripdata.csv')
# file_2 = os.path.join('Data','2013-08-citibike-tripdata.csv')
# file_3 = os.path.join('Data','2013-10-citibike-tripdata.csv')
# file_4 = os.path.join('Data','2013-12-citibike-tripdata.csv')
# file_5 = os.path.join('Data','2014-02-citibike-tripdata.csv')
# file_6 = os.path.join('Data','2014-04-citibike-tripdata.csv')
# file_8 = os.path.join('Data','2014-06-citibike-tripdata.csv')
# file_9 = os.path.join('Data','2014-08-citibike-tripdata.csv')
# file_10 = os.path.join ....

# %%
# glob it
df = []
import glob

for i in glob.glob('Data_Test/*.csv'):
    csv_i = pd.read_csv(i, index_col=None, header=0)
    #print(csv_i)
    df.append(csv_i)
    master_df= pd.concat(df, ignore_index=True)

master_df
# Out:
#          tripduration            starttime             stoptime  \
# 0                 695  2013-06-01 00:00:01  2013-06-01 00:11:36
# 1                 693  2013-06-01 00:00:08  2013-06-01 00:11:41
# 2                2059  2013-06-01 00:00:44  2013-06-01 00:35:03
# 3                 123  2013-06-01 00:01:04  2013-06-01 00:03:07
# 4                1521  2013-06-01 00:01:22  2013-06-01 00:26:43
# 5                2028  2013-06-01 00:01:47  2013-06-01 00:35:35
# 6                2057  2013-06-01 00:02:33  2013-06-01 00:36:50
# 7                 369  2013-06-01 00:03:29  2013-06-01 00:09:38
# 8                1829  2013-06-01 00:03:47  2013-06-01 00:34:16
# 9                 829  2013-06-01 00:04:22  2013-06-01 00:18:11
# 10               1316  2013-06-01 00:04:28  2013-06-01 00:26:24
# 11               1456  2013-06-01 00:04:41  2013-06-01 00:28:57
# 12                386  2013-06-01 00:05:13  2013-06-01 00:11:39
# 13                924  2013-06-01 00:05:21  2013-06-01 00:20:45
# ...

# %%
#FOR THE BOLD
# df = []
# import glob

# for i in glob.glob('Data/*.csv'):
#     csv_i = pd.read_csv(i, index_col=None, header=0)
#     #print(csv_i)
#     df.append(csv_i)
#     master_df= pd.concat(df, ignore_index=True)

# master_df

# %%
master_df.reset_index()
# Out:
#            index  tripduration            starttime             stoptime  \
# 0              0           695  2013-06-01 00:00:01  2013-06-01 00:11:36
# 1              1           693  2013-06-01 00:00:08  2013-06-01 00:11:41
# 2              2          2059  2013-06-01 00:00:44  2013-06-01 00:35:03
# 3              3           123  2013-06-01 00:01:04  2013-06-01 00:03:07
# 4              4          1521  2013-06-01 00:01:22  2013-06-01 00:26:43
# 5              5          2028  2013-06-01 00:01:47  2013-06-01 00:35:35
# 6              6          2057  2013-06-01 00:02:33  2013-06-01 00:36:50
# 7              7           369  2013-06-01 00:03:29  2013-06-01 00:09:38
# 8              8          1829  2013-06-01 00:03:47  2013-06-01 00:34:16
# 9              9           829  2013-06-01 00:04:22  2013-06-01 00:18:11
# 10            10          1316  2013-06-01 00:04:28  2013-06-01 00:26:24
# 11            11          1456  2013-06-01 00:04:41  2013-06-01 00:28:57
# ...

# %%
master_df.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           695  2013-06-01 00:00:01  2013-06-01 00:11:36               444
# 1           693  2013-06-01 00:00:08  2013-06-01 00:11:41               444
# 2          2059  2013-06-01 00:00:44  2013-06-01 00:35:03               406
# 3           123  2013-06-01 00:01:04  2013-06-01 00:03:07               475
# 4          1521  2013-06-01 00:01:22  2013-06-01 00:26:43              2008
#
#        start station name  start station latitude  start station longitude  \
# 0      Broadway & W 24 St               40.742354               -73.989151
# 1      Broadway & W 24 St               40.742354               -73.989151
# 2  Hicks St & Montague St               40.695128               -73.995951
# 3     E 15 St & Irving Pl               40.735243               -73.987586
# 4   Little West St & 1 Pl               40.705693               -74.016777
#
# ...

# %%
master_df[-3:]
# Out:
#          tripduration            starttime             stoptime  \
# 3061336          1520  2013-12-31 23:57:44  2014-01-01 00:23:04
# 3061337          1166  2013-12-31 23:58:14  2014-01-01 00:17:40
# 3061338           677  2013-12-31 23:58:16  2014-01-01 00:09:33
#
#          start station id                 start station name  \
# 3061336               281  Grand Army Plaza & Central Park S
# 3061337               492                    W 33 St & 7 Ave
# 3061338               463                    9 Ave & W 16 St
#
#          start station latitude  start station longitude  end station id  \
# 3061336               40.764397               -73.973715           411.0
# 3061337               40.750200               -73.990931           253.0
# 3061338               40.742065               -74.004432           448.0
#
#           end station name  end station latitude  end station longitude  \
# 3061336  E 6 St & Avenue D             40.722281             -73.976687
# ...

# %%
#rename index and export
master_df = master_df.rename(columns={'index':'rideid'})

# %%
master_df.to_csv('citibike.csv',index=False)
